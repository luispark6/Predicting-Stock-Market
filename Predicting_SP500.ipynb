# %%
import yfinance as yf

# %%
s500 = yf.Ticker("^GSPC")

# %%
s500 = s500.history(period="max") #queries all data since the index was created

# %%
s500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-04-26 00:00:00-04:00  4087.780029  4089.669922  4049.350098  4055.989990
# 2023-04-27 00:00:00-04:00  4075.290039  4138.240234  4075.290039  4135.350098
# 2023-04-28 00:00:00-04:00  4129.629883  4170.060059  4127.180176  4169.479980
# 2023-05-01 00:00:00-04:00  4166.790039  4186.919922  4164.120117  4167.870117
# 2023-05-02 00:00:00-04:00  4164.100098  4164.100098  4089.719971  4119.580078
#
# ...

# %%
del s500["Dividends"] #deleting dividends column because not useful information

# %%
del s500["Stock Splits"] #deletng stock splits column because not useful information

# %%
s500["Tomorrow_Close"] = s500["Close"].shift(-1) #this creates a new column for each row
#and shows the next days closing price. This will be used to see if stock prices increased
#or decreased in one day

# %%
s500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-04-26 00:00:00-04:00  4087.780029  4089.669922  4049.350098  4055.989990
# 2023-04-27 00:00:00-04:00  4075.290039  4138.240234  4075.290039  4135.350098
# 2023-04-28 00:00:00-04:00  4129.629883  4170.060059  4127.180176  4169.479980
# 2023-05-01 00:00:00-04:00  4166.790039  4186.919922  4164.120117  4167.870117
# 2023-05-02 00:00:00-04:00  4164.100098  4164.100098  4089.719971  4119.580078
#
# ...

# %%
s500["Increase_Money"] = (s500["Tomorrow_Close"]>s500["Close"]).astype(int) #creating a new column that 
#indicates if the stock prices goes up(1) the next day or goes down(0)

# %%
s500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-04-26 00:00:00-04:00  4087.780029  4089.669922  4049.350098  4055.989990
# 2023-04-27 00:00:00-04:00  4075.290039  4138.240234  4075.290039  4135.350098
# 2023-04-28 00:00:00-04:00  4129.629883  4170.060059  4127.180176  4169.479980
# 2023-05-01 00:00:00-04:00  4166.790039  4186.919922  4164.120117  4167.870117
# 2023-05-02 00:00:00-04:00  4164.100098  4164.100098  4089.719971  4119.580078
#
# ...

# %%
s500 = s500.loc["2000-01-01":].copy()

# %%
s500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-03 00:00:00-05:00  1469.250000  1478.000000  1438.359985  1455.219971
# 2000-01-04 00:00:00-05:00  1455.219971  1455.219971  1397.430054  1399.420044
# 2000-01-05 00:00:00-05:00  1399.420044  1413.270020  1377.680054  1402.109985
# 2000-01-06 00:00:00-05:00  1402.109985  1411.900024  1392.099976  1403.449951
# 2000-01-07 00:00:00-05:00  1403.449951  1441.469971  1400.729980  1441.469971
# ...                                ...          ...          ...          ...
# 2023-04-26 00:00:00-04:00  4087.780029  4089.669922  4049.350098  4055.989990
# 2023-04-27 00:00:00-04:00  4075.290039  4138.240234  4075.290039  4135.350098
# 2023-04-28 00:00:00-04:00  4129.629883  4170.060059  4127.180176  4169.479980
# 2023-05-01 00:00:00-04:00  4166.790039  4186.919922  4164.120117  4167.870117
# 2023-05-02 00:00:00-04:00  4164.100098  4164.100098  4089.719971  4119.580078
#
# ...
